# %%
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

# %% [markdown]
# # imshow()的作用是将数组数据转换为图像

# %%
img = Image.open('img1.jpg')
data = np.array(img)
plt.figure(figsize=(10, 10), dpi=100)
plt.axis('off')
plt.imshow(data)
plt.show()
